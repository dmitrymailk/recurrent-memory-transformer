# %%
import wandb

# заблокирован в РФ
run = wandb.init(
    project="finetune_babilong_qa1_rmt_vary_n_seg_iter_tasks_curriculum",  # Specify your project
    config={  # Track hyperparameters and metadata
        "learning_rate": 0.01,
        "epochs": 10,
    },
)
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import wandb
# ----> 3 run = wandb.init(
#       4     project="finetune_babilong_qa1_rmt_vary_n_seg_iter_tasks_curriculum",  # Specify your project
#       5     config={  # Track hyperparameters and metadata
#       6         "learning_rate": 0.01,
#       7         "epochs": 10,
#       8     },
#       9 )
#
# File ~/.local/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:1620, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
# ...
